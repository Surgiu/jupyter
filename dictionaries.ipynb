# %% [markdown]
# # dictionaries

# %% [markdown]
# ## 1.fundamentals

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the `dict` function

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
eg1 = dict()
eg1

# %%
eg1['first'] = 'one'
eg1

# %%
eg1['second'] = 'two'
eg1

# %%
eg1['third'] = 'three'
eg1['second']

# %%
len(eg1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# the `in` operation

# %%
print('one' in eg1)
print('first' in eg1)

# %% [markdown]
# the `values` method

# %%
'one' in eg1.values()

# %% [markdown]
# the `get` method

# %%
eg1.get('first', 0)

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ## 2.1 case study: dictionary as a counter

# %%
def histogram(s):
    """this is a function that counts the number of times a letter appears in a string"""
    d = dict()
    for c in s:
        d[c] = d.get(c, 0) + 1
    return d


histogram('brontosaurus')

# %%
def invert_dict(d):
    """this is a function that inverts a dictionary"""
    inverse = dict()
    for key in d:
        val = d[key]
        if val not in inverse:
            inverse[val] = [key]
        else:
            inverse[val].append(key)
    return inverse


hist = histogram('parrot')
inverse = invert_dict(hist)
inverse

# %% [markdown]
# **Lists can be values in a dictionary, as this example shows, but they cannot be keys.**

# %% [markdown]
# ## 2.2 case study: memos

# %%
known = {0: 0, 1: 1}  # note that the dictionary is a global variable


def fibonacci(n):
    if n in known:
        return known[n]
    res = fibonacci(n-1) + fibonacci(n-2)
    print(res)  # print the result
    known[n] = res  # store the result in known
    print(known) # print the dictionary
    return res


fibonacci(10)

# %% [markdown]
# ## 3. global variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# How to reassign a global variable inside a function:

# %% [markdown]
# ```Python
# been_called = False
# def example2():
#     global been_called
#     been_called = True
# ```
